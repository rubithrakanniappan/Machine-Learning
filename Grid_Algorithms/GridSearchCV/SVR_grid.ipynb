# %%
#impoting the libaries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Here we load the dataset from the insurance.csv file
dataset = pd.read_csv("insurance.csv")
#Check the dataset data in table format
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#pandas.get_dummies() is used for data manipulation. It converts categorical data into dummy or indicator variables.
#drop_first=True - Remove first level to get n-1 dummies out of n categorical level
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#Check the dataset after drop first column from dummies
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# it returns the column labels of the dataset
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Split the inputs
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
#Split the inputs
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
               'C':[10,100,1000,2000,3000]}

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\aravi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#print the best parameter after tunning
re = grid.cv_results_
print("R score value for best parameter {}:".format(grid.best_params_))
# Out:
# R score value for best parameter {'C': 1000, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.738220      0.053411         0.259964        0.015531      10
# 1        0.589281      0.063825         0.081077        0.051952      10
# 2        1.024634      0.542883         0.124071        0.013922      10
# 3        0.600336      0.076724         0.086874        0.033734      10
# 4        0.682476      0.086158         0.312690        0.058981     100
# 5        0.696258      0.032243         0.071457        0.060280     100
# 6        0.836994      0.045810         0.190899        0.060378     100
# 7        1.377584      0.114008         0.098111        0.056999     100
# 8        0.699725      0.103756         0.241152        0.060643    1000
# 9        0.912334      0.083221         0.113322        0.045588    1000
# 10       0.876302      0.099981         0.184722        0.035555    1000
# 11       4.990552      0.323091         0.142804        0.063424    1000
# 12       0.885411      0.082547         0.383427        0.109418    2000
# 13       0.930864      0.125861         0.057979        0.041967    2000
# 14       0.653309      0.086973         0.128185        0.013822    2000
# 15       8.079622      1.430208         0.115405        0.071290    2000
# 16       0.804211      0.051446         0.301893        0.048733    3000
# 17       1.076265      0.137448         0.094254        0.038071    3000
# 18       0.686744      0.053703         0.140093        0.038402    3000
# 19      13.339919      3.680941         0.089042        0.057433    3000
#
#    param_kernel                            params  split0_test_score  \
# 0           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 1          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 2       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 3        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 4           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 5          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 6       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 7        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 8           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 9          poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 10      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 11       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 12          rbf      {'C': 2000, 'kernel': 'rbf'}          -0.143510
# 13         poly     {'C': 2000, 'kernel': 'poly'}          -0.020567
# 14      sigmoid  {'C': 2000, 'kernel': 'sigmoid'}          -7.209317
# 15       linear   {'C': 2000, 'kernel': 'linear'}           0.682349
# 16          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 17         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 18      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
# 19       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.097459          -0.074488          -0.099597
# 1           -0.081505          -0.111907          -0.131602
# 2           -0.119312          -0.085214          -0.108210
# 3            0.029886           0.022167           0.003112
# 4           -0.107253          -0.123430          -0.137753
# 5           -0.082461          -0.129220          -0.139962
# 6           -0.160831          -0.117544          -0.137984
# 7            0.521798           0.547691           0.538805
# 8           -0.098267          -0.123724          -0.137137
# 9           -0.028469          -0.073376          -0.086611
# 10          -2.686121          -2.194563          -2.210858
# 11           0.675162           0.680002           0.699377
# 12          -0.087595          -0.113312          -0.128591
# 13           0.035685          -0.011468          -0.024587
# 14          -9.282940          -7.776578          -7.745074
# 15           0.630642           0.750714           0.646368
# 16          -0.075578          -0.100199          -0.116051
# 17           0.098496           0.049291           0.035615
# 18         -20.498908         -17.095474         -16.750877
# 19           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.124428        -0.101276        0.016459                9
# 1           -0.179328        -0.125899        0.031794               12
# 2           -0.108716        -0.107639        0.012029               10
# 3           -0.066653        -0.006086        0.034672                6
# 4           -0.209551        -0.147634        0.035511               17
# 5           -0.189219        -0.134749        0.033948               14
# 6           -0.130402        -0.137843        0.014263               15
# 7            0.508518         0.535225        0.018122                4
# 8           -0.206405        -0.144193        0.036262               16
# 9           -0.134493        -0.080695        0.033795                8
# 10          -1.942521        -2.215441        0.255409               18
# 11           0.677952         0.693778        0.022955                1
# 12          -0.193992        -0.133400        0.035492               13
# 13          -0.076360        -0.019459        0.035693                7
# 14          -6.891719        -7.781126        0.821557               19
# 15           0.722261         0.686467        0.045056                2
# 16          -0.179304        -0.120018        0.034578               11
# 17          -0.020924         0.040035        0.038064                5
# 18         -15.012168       -16.983856        1.914783               20
# 19           0.698692         0.673914        0.039876                3

# %%
age_input= float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("Children:"))
sex_male_input = int(input("Sex Male 0 or 1:"))
smoker_yes_input = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future Prediction {}:".format(Future_Prediction))
# Out:
# Future Prediction [30603.97369964]:
# C:\Users\aravi\Anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   "X does not have valid feature names, but"
